# %%
def gen_demo():

    yield "first"
    yield "second"
    yield "third"

# %% [markdown]
# when a genrator function is called it gives a genrator function object

# %%
gen = gen_demo()

print(next(gen))
print(next(gen))
# Out:
# first
# second

# %%
def gen_demo():

    yield "first"
    yield "second"
    yield "third"

gen = gen_demo()

for i in gen:
    print(i)
# Out:
# first
# second
# third
